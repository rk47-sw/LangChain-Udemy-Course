# %% [markdown]
# # Tool Calling with Gemini
#
#
# OpenAI's function calling was first deprecated in favor of tool calling - but now the correct term seems to be function calling again.
#
#
# If you call it tool- or function calling - at the moment it does not really matter.
#
#
# Reference: https://platform.openai.com/docs/guides/function-calling

# %%
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())
from langchain_google_genai import ChatGoogleGenerativeAI



llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

llm.invoke("How will the weather be in munich today?")
# Out:
# AIMessage(content='I can\'t give you real-time, live weather updates for Munich today, as my information isn\'t current to the minute.\n\nHowever, you can easily get the most accurate, up-to-the-second forecast by checking:\n\n*   **A quick Google search:** Just type "weather Munich today" into your search engine.\n*   **Weather apps:** Check popular apps like AccuWeather, The Weather Channel, or your phone\'s built-in weather app.\n*   **Weather websites:** Visit sites like AccuWeather.com, Weather.com, or the German Meteorological Service (DWD) website.\n*   **Voice assistants:** Ask Siri, Alexa, or Google Assistant "What\'s the weather in Munich today?"', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c942e-15a8-7142-b972-76b6b789748a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 764, 'total_tokens': 775, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 607}})

# %% [markdown]
# ## Approach 1: Using @tool decorator (Recommended)

# %%
from langchain_core.tools import tool



# @tool

# def fake_weather_api(city: str) -> str:

#     """

#     Check the weather in a specified city.



#     Args:

#         city (str): The name of the city where you want to check the weather.



#     Returns:

#         str: A description of the current weather in the specified city.

#     """

#     return "Sunny, 22°C"



# @tool

# def outdoor_seating_availability(city: str) -> str:

#     """

#     Check if outdoor seating is available at a specified restaurant in a given city.



#     Args:

#         city (str): The name of the city where you want to check for outdoor seating availability.



#     Returns:

#         str: A message stating whether outdoor seating is available or not.

#     """

#     return "Outdoor seating is available."



# tools = [fake_weather_api, outdoor_seating_availability]

# %% [markdown]
# ## Approach 2: Using Pydantic classes
#
#
# Note: If using this approach, you must also update the tool_mapping cell below to use the correct tool names.

# %%
# Alternative: Using Pydantic classes for tool definitions

# To use this approach:

# 1. Comment out the @tool decorator cell above

# 2. Uncomment this cell

# 3. Update the tool_mapping cell below to use correct names



from pydantic import BaseModel, Field



class fake_weather_api(BaseModel):

    """Check the weather in a specified city."""

    city: str = Field(..., description="Name of the city to check the weather for")



class outdoor_seating_availability(BaseModel):

    """Check if outdoor seating is available at a specified restaurant in a given city."""

    city: str = Field(..., description="Name of the city where the restaurant is located")



# Actual functions that return the tool outputs
def get_weather(city: str) -> str:
    """Get the weather for a specified city."""
    return "Sunny, 22°C"

def get_outdoor_seating(city: str) -> str:
    """Check if outdoor seating is available."""
    return "Outdoor seating is available."



# Convert Pydantic classes to callable StructuredTools
from langchain_core.tools import StructuredTool



fake_weather_tool = StructuredTool.from_function(
    func=get_weather,
    name="fake_weather_api",
    description="Check the weather in a specified city.",
    args_schema=fake_weather_api
)

outdoor_seating_tool = StructuredTool.from_function(
    func=get_outdoor_seating,
    name="outdoor_seating_availability",
    description="Check if outdoor seating is available at a specified restaurant in a given city.",
    args_schema=outdoor_seating_availability
)



tools = [fake_weather_tool, outdoor_seating_tool]

# %%
llm_with_tools = llm.bind_tools(tools)
result = llm_with_tools.invoke("How will the weather be in munich today?")

result
# Out:
# AIMessage(content='', additional_kwargs={'function_call': {'name': 'fake_weather_api', 'arguments': '{"city": "munich"}'}, '__gemini_function_call_thought_signatures__': {'836fb521-023f-4b3f-b710-e3fd7e9d859a': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c942e-5aba-7c83-82f8-75b21334f963-0', tool_calls=[{'name': 'fake_weather_api', 'args': {'city': 'munich'}, 'id': '836fb521-023f-4b3f-b710-e3fd7e9d859a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 119, 'output_tokens': 78, 'total_tokens': 197, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 60}})

# %%
result = llm_with_tools.invoke(

    "How will the weather be in munich today? Do you still have seats outdoor available?"

)

result
# Out:
# AIMessage(content='', additional_kwargs={'function_call': {'name': 'fake_weather_api', 'arguments': '{"city": "munich"}'}, '__gemini_function_call_thought_signatures__': {'5f047bdf-f6d4-49ed-a812-a8d775a52570': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c942f-420b-7352-9ac0-b24bf5531c9e-0', tool_calls=[{'name': 'fake_weather_api', 'args': {'city': 'munich'}, 'id': '5f047bdf-f6d4-49ed-a812-a8d775a52570', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 127, 'output_tokens': 188, 'total_tokens': 315, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 170}})

# %%
result.tool_calls
# Out:
# [{'name': 'fake_weather_api',
#   'args': {'city': 'munich'},
#   'id': '5f047bdf-f6d4-49ed-a812-a8d775a52570',
#   'type': 'tool_call'}]

# %%
from langchain_core.messages import HumanMessage, ToolMessage



messages = [

    HumanMessage(

        "How will the weather be in munich today? I would like to eat outside if possible"

    )

]

llm_output = llm_with_tools.invoke(messages)

messages.append(llm_output)
messages
# Out:
# [HumanMessage(content='How will the weather be in munich today? I would like to eat outside if possible', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'function_call': {'name': 'outdoor_seating_availability', 'arguments': '{"city": "munich"}'}, '__gemini_function_call_thought_signatures__': {'724b9cc2-04d8-45bc-8295-a526fcf1801f': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c942f-5ede-7511-a2b9-f85267cdabe3-0', tool_calls=[{'name': 'fake_weather_api', 'args': {'city': 'munich'}, 'id': '724b9cc2-04d8-45bc-8295-a526fcf1801f', 'type': 'tool_call'}, {'name': 'outdoor_seating_availability', 'args': {'city': 'munich'}, 'id': '8fc9c0d0-fec5-42c7-b2fd-f0a872374a8f', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 127, 'output_tokens': 98, 'total_tokens': 225, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 61}})]

# %%
# Tool mapping for @tool decorator approach (default)

# tool_mapping = {

#     "fake_weather_api": fake_weather_api,

#     "outdoor_seating_availability": outdoor_seating_availability,

# }



# For Pydantic approach, use this mapping instead:

tool_mapping = {

    "fake_weather_api": fake_weather_tool,

    "outdoor_seating_availability": outdoor_seating_tool,

}

# %%
for tool_call in llm_output.tool_calls:

    tool = tool_mapping[tool_call["name"].lower()]

    tool_output = tool.invoke(tool_call["args"])

    messages.append(ToolMessage(tool_output, tool_call_id=tool_call["id"]))

# %%
messages
# Out:
# [HumanMessage(content='How will the weather be in munich today? I would like to eat outside if possible', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'function_call': {'name': 'outdoor_seating_availability', 'arguments': '{"city": "munich"}'}, '__gemini_function_call_thought_signatures__': {'724b9cc2-04d8-45bc-8295-a526fcf1801f': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c942f-5ede-7511-a2b9-f85267cdabe3-0', tool_calls=[{'name': 'fake_weather_api', 'args': {'city': 'munich'}, 'id': '724b9cc2-04d8-45bc-8295-a526fcf1801f', 'type': 'tool_call'}, {'name': 'outdoor_seating_availability', 'args': {'city': 'munich'}, 'id': '8fc9c0d0-fec5-42c7-b2fd-f0a872374a8f', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 127, 'output_tokens': 98, 'total_tokens': 225, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 61}}),
#  ToolMessage(content='Sunny, 22°C', tool_call_id='724b9cc2-04d8-45bc-8295-a526fcf1801f'),
#  ToolMessage(content='Outdoor seating is available.', tool_call_id='8fc9c0d0-fec5-42c7-b2fd-f0a872374a8f')]

# %%
llm_with_tools.invoke(messages)
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'It is sunny with a temperature of 22°C in Munich today. Outdoor seating is available.', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c942f-9660-7002-88a6-58ec336f196d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 207, 'output_tokens': 83, 'total_tokens': 290, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 62}})
